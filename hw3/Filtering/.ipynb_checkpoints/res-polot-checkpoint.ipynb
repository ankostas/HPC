# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
# nvcc blurring.cu -I./  
#./a.out edge
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(Image.open("corgi.jpg"))
plt.axis("off")

plt.subplot(122)
plt.imshow(Image.open("res_corgi.jpg"))
plt.axis("off")
plt.show()

# %%
# nvcc blurring.cu -I./  
#./a.out sharpen
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(Image.open("corgi.jpg"))
plt.axis("off")

plt.subplot(122)
plt.imshow(Image.open("res_corgi.jpg"))
plt.axis("off")
plt.show()

# %%
# nvcc blurring.cu -I./  
#./a.out gaussian
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(Image.open("corgi.jpg"))
plt.axis("off")

plt.subplot(122)
plt.imshow(Image.open("res_corgi.jpg"))
plt.axis("off")
plt.show()

# %%
# nvcc median.cu -I./  
#./a.out 
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(Image.open("corgi.jpg"))
plt.axis("off")

plt.subplot(122)
plt.imshow(Image.open("res_corgi.jpg"))
plt.axis("off")
plt.show()
